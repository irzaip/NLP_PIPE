# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# After the data cleaning step where we put our data into a few standard formats, the next step is to take a look at the data and see if what we're looking at makes sense. Before applying any fancy algorithms, it's always important to explore the data first.
#
# When working with numerical data, some of the exploratory data analysis (EDA) techniques we can use include finding the average of the data set, the distribution of the data, the most common values, etc. The idea is the same when working with text data. We are going to find some more obvious patterns with EDA before identifying the hidden patterns with machines learning (ML) techniques. We are going to look at the following for each comedian:
#
# 1. **Most common words** - find these and create word clouds
# 2. **Size of vocabulary** - look number of unique words and also how quickly someone speaks
# 3. **Amount of profanity** - most common terms

# %% [markdown]
# ## Most Common Words

# %% [markdown]
# ### Analysis

# %%
# Read in the document-term matrix
import pandas as pd

data = pd.read_pickle('d-dtm.pkl')
data = data.transpose()
data.head()
# Out:
# user      fadlizon  fahri  msaid
# abaaah           0      0      1
# abadi            2      0      0
# abalabal         4      0      0
# abd              1      0      0
# abdul            1      0      0

# %%
# Find the top 30 words said by each comedian
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'fadlizon': [('fadli', 974),
#   ('zon', 933),
#   ('di', 494),
#   ('ini', 446),
#   ('pemerintah', 386),
#   ('yg', 333),
#   ('dan', 306),
#   ('tak', 255),
#   ('jokowi', 252),
#   ('kita', 237),
#   ('untuk', 208),
#   ('yang', 195),
#   ('indonesia', 188),
#   ('sy', 172),
#   ('itu', 168),
#   ('ada', 162),
#   ('corona', 158),
#   ('bisa', 157),
#   ('rakyat', 145),
#   ('dari', 141),
#   ('soal', 127),
#   ('dengan', 125),
#   ('dalam', 123),
#   ('presiden', 116),
#   ('bukan', 113),
#   ('ke', 112),
#   ('harus', 111),
#   ('lockdown', 109),
#   ('tahun', 106),
#   ('negara', 106)],
#  'fahri': [('dan', 44),
#   ('yang', 37),
#   ('ini', 30),
#   ('di', 29),
#   ('kita', 24),
#   ('ada', 20),
#   ('ya', 17),
#   ('dalam', 17),
#   ('apa', 15),
#   ('dari', 15),
#   ('saya', 14),
#   ('untuk', 13),
#   ('pak', 12),
#   ('gak', 11),
#   ('tidak', 11),
#   ('lagi', 10),
#   ('orang', 10),
#   ('adalah', 10),
#   ('jangan', 10),
#   ('baru', 10),
#   ('dengan', 9),
#   ('negara', 9),
#   ('pada', 9),
#   ('yg', 9),
#   ('sudah', 8),
#   ('yuk', 8),
#   ('corona', 8),
#   ('malam', 7),
#   ('bagi', 7),
#   ('kepada', 7)],
#  'msaid': [('rt', 171),
#   ('di', 43),
#   ('ini', 27),
#   ('yg', 26),
#   ('yang', 24),
#   ('msaiddidu', 18),
#   ('corona', 17),
#   ('saya', 17),
#   ('dan', 16),
#   ('teror', 12),
#   ('ada', 12),
#   ('dari', 11),
#   ('ke', 11),
#   ('pak', 10),
#   ('ruslan', 10),
#   ('ugm', 10),
#   ('buton', 10),
#   ('tvri', 10),
#   ('itu', 10),
#   ('amp', 9),
#   ('cnnindonesia', 9),
#   ('jadi', 9),
#   ('akun', 9),
#   ('indonesia', 9),
#   ('minta', 9),
#   ('dirut', 9),
#   ('akan', 8),
#   ('presiden', 8),
#   ('juga', 8),
#   ('untuk', 8)]}

# %%
# Print the top 15 words said by each comedian
for comedian, top_words in top_dict.items():
    print(comedian)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# fadlizon
# fadli, zon, di, ini, pemerintah, yg, dan, tak, jokowi, kita, untuk, yang, indonesia, sy
# ---
# fahri
# dan, yang, ini, di, kita, ada, ya, dalam, apa, dari, saya, untuk, pak, gak
# ---
# msaid
# rt, di, ini, yg, yang, msaiddidu, corona, saya, dan, teror, ada, dari, ke, pak
# ---

# %% [markdown]
# **NOTE:** At this point, we could go on and create word clouds. However, by looking at these top words, you can see that some of them have very little meaning and could be added to a stop words list, so let's do just that.

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each comedian
words = []
for comedian in data.columns:
    top = [word for (word, count) in top_dict[comedian]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['fadli',
#  'zon',
#  'di',
#  'ini',
#  'pemerintah',
#  'yg',
#  'dan',
#  'tak',
#  'jokowi',
#  'kita',
#  'untuk',
#  'yang',
#  'indonesia',
#  'sy',
#  'itu',
#  'ada',
#  'corona',
#  'bisa',
#  'rakyat',
#  'dari',
#  'soal',
#  'dengan',
#  'dalam',
#  'presiden',
#  'bukan',
#  'ke',
#  'harus',
#  'lockdown',
#  'tahun',
#  'negara',
#  'dan',
#  'yang',
#  'ini',
#  'di',
#  'kita',
#  'ada',
#  'ya',
#  'dalam',
#  'apa',
#  'dari',
#  'saya',
#  'untuk',
#  'pak',
#  'gak',
#  'tidak',
#  'lagi',
#  'orang',
#  'adalah',
#  'jangan',
#  'baru',
#  'dengan',
#  'negara',
#  'pada',
#  'yg',
#  'sudah',
#  'yuk',
#  'corona',
#  'malam',
#  'bagi',
#  'kepada',
#  'rt',
#  'di',
#  'ini',
#  'yg',
#  'yang',
#  'msaiddidu',
#  'corona',
#  'saya',
#  'dan',
#  'teror',
#  'ada',
#  'dari',
#  'ke',
#  'pak',
#  'ruslan',
#  'ugm',
#  'buton',
#  'tvri',
#  'itu',
#  'amp',
#  'cnnindonesia',
#  'jadi',
#  'akun',
#  'indonesia',
#  'minta',
#  'dirut',
#  'akan',
#  'presiden',
#  'juga',
#  'untuk']

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('di', 3),
#  ('ini', 3),
#  ('yg', 3),
#  ('dan', 3),
#  ('untuk', 3),
#  ('yang', 3),
#  ('ada', 3),
#  ('corona', 3),
#  ('dari', 3),
#  ('kita', 2),
#  ('indonesia', 2),
#  ('itu', 2),
#  ('dengan', 2),
#  ('dalam', 2),
#  ('presiden', 2),
#  ('ke', 2),
#  ('negara', 2),
#  ('saya', 2),
#  ('pak', 2),
#  ('fadli', 1),
#  ('zon', 1),
#  ('pemerintah', 1),
#  ('tak', 1),
#  ('jokowi', 1),
#  ('sy', 1),
#  ('bisa', 1),
#  ('rakyat', 1),
#  ('soal', 1),
#  ('bukan', 1),
#  ('harus', 1),
#  ('lockdown', 1),
#  ('tahun', 1),
#  ('ya', 1),
#  ('apa', 1),
#  ('gak', 1),
#  ('tidak', 1),
#  ('lagi', 1),
#  ('orang', 1),
#  ('adalah', 1),
#  ('jangan', 1),
#  ('baru', 1),
#  ('pada', 1),
#  ('sudah', 1),
#  ('yuk', 1),
#  ('malam', 1),
#  ('bagi', 1),
#  ('kepada', 1),
#  ('rt', 1),
#  ('msaiddidu', 1),
#  ('teror', 1),
#  ('ruslan', 1),
#  ('ugm', 1),
#  ('buton', 1),
#  ('tvri', 1),
#  ('amp', 1),
#  ('cnnindonesia', 1),
#  ('jadi', 1),
#  ('akun', 1),
#  ('minta', 1),
#  ('dirut', 1),
#  ('akan', 1),
#  ('juga', 1)]

# %%
# If more than half of the comedians have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 6]
add_stop_words
# Out:
# []

# %%
# Let's update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer

# Read in cleaned data
data_clean = pd.read_pickle('data_clean.pkl')

# Add new stop words
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean[2])
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_stop.index = data_clean.index

# Pickle it for later use
import pickle
pickle.dump(cv, open("cv_stop.pkl", "wb"))
data_stop.to_pickle("dtm_stop.pkl")

# %%
# Let's make some word clouds!
# Terminal / Anaconda Prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
str(data_clean[2].tolist())
# Out:
# "['pemerintah harus menjadi medium bagi keramahan negara jadilah yang rendah hati lemah lembut dan bersahabat dalam kesulitan ada kemudahan dan ada hikmah mari kita bersatu dan menyatukan jangan menjadi medium pertengkaran negara dan pemerintah harus cerdas dan dewasa', 'sekedar mengingatkan agar ruang publik kita tetap menjadi medium bagi keramahan negara kepada warganya kita memang pakai masker tapi kita harus tetap tau cara tersenyum keramahan negara adalah jalan bagi kita untuk bersatu menghadapi tantangan negara jangan tegang', 'kejadian kematian georgefloyd yang berakibat merusuhan sosial adalah peringatan kepada aparat jangan bertindak berlebihan dalam krisis kayak gini orang amerika saja jadi gak rasional aparat jangan berlebihan pertumbangkan keasulitan orang lagi sensitif akibat covid', 'kerusuhan di amerika di mulai di minnesota yang sebetulnya punya tradisi plural beberapa anggota kongres datang dari daerah itu tidak saja afroamerican tapi muslim seperti ilhan omar dan keith elison ledakan akibat kematian georgefloyd cepat sekali semoga cepat berlalu', 'lebih baik pemerintah di manapun terbuka dan jujur newnormal', 'kayaknya paman donald serius nih gaes ', 'yuk biar paham kenapa isu komunis muncul lagi', 'pak menteri pakai masker mereknya apa ya', ' keseringan pakai masker kamu jadi tidak lupa arti ramah kan sayang ', 'masker jangan bikin kamu berhenti tersenyum sayang', 'habisnya yang ada konfrensi pers pada ngomongin diadianya kagak pernah konfrensi perskhawatir  salah paham padanya', 'kapan virus corona konfrensi pers ya pengen nanya', 'cc trump', 'keakraban  tokoh ini berperan menanam benih tradisi berpikir sayaalfatehah buat caknur dan gusdur dan kita doakan caknun sehat terus mengawal akal sehat bangsa kita amin', 'trump meninjau mall dan stasiun katanya untuk memastikanapa yang pasti', 'gitu lo trump tak kandani kok ra percoyo', 'ini ilmu umum bukan soal penguasa sekarang di gedung putih atau hitambahwa jika keputusan tidak pakai ilmu pasti berantakan', 'negara memang awalnya imajinasitapi ketika ia telah menjadi struktur dan karena itu punya sistematikasaat krisis maka sistematika harus dipakai bertindak negara yang tidak sistematis adalah calon negara gagal', 'kebijakan ujugujug dalam jangka panjang akan gujuguju ', 'kebijakan negara yang terkait melindungi segenap bangsa indonesia dan menyangkut hajat hidup orang banyak harus transparan transparansi bukan dalam bentuk kunjungan lapangan tapi argumen inplementasi serta konsistensi konsistensi adalah yg terpenting', 'lebaran online  jatim grebeg tokoh gelora', 'eksport yuk', 'mereknya apa ya ', 'pilihan anda', 'perlombaan anti china akan menjadi isu utama dan inti dalam pilpres amerika november manti', 'inconsistency is anewnormal ', 'masak yg dagang boleh dagang yang kritik gak boleh keitik sih', 'إلى إخواني وأخواتي المسلمين، أينما كنت ، اسمح لنا ولعائلتك بمرافقتك في سعادة عيد مبارك  ، تقبل الله جميع أعمالنا آمين  to my muslim brothers and sisters allow me and family to accompany you in the happiness of ied mubarak  may allah accept all our deedsamin', 'ramadan dan iedul fitri tahun  ini tidak mudah di tengah pandemi  semoga allah swt merima amal memberi kekuatan dan ketegaran untuk  bulan kedepan selamat iedul fitri  taqobbalallahu minna wa minkum ayo bangkit dengan gelombangsolidaritas ', 'iedmubarak ', 'dapat kiriman sambal dari tatagibrig namanya sambal pasti pedestapi ini pedes dan maknyus silahkan dipesanini hp   untuk sambal opor ', 'hariterakhir ', 'ibu prof dr siti fadilah adalah korban dari hukum yang dijalankan dengan dendam sehingga tidak sensitif terhadap  azaz manfaat dalam hukum akhirnya manfaat hukum dipakai untuk musuh negara bukan untuk bangsa sendiri bebaskansitifadilah', 'terima kasih atas pandangan yang berani ', 'bebaskansitifadilah baru dengar beliau mendadak ditarik lagi ke lapas pondok bambu padahal rabu kemarin diamankan ke rdpad gatot subroto karena lapas jadi zona merah usia beliau  tahun tapi masih ditahan macam orang berbahaya ...

# %%
wc.generate(str(data_clean[2].tolist()))
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wc) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-acc256bb92ad> in <module>
#       1 wc.generate(str(data_clean[2].tolist()))
#       2 # plot the WordCloud image
# ----> 3 plt.figure(figsize = (8, 8), facecolor = None)
#       4 plt.imshow(wc)
#       5 plt.axis("off")
#
# NameError: name 'plt' is not defined

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

full_names = ['fadlizon','fahri','msdidu']

# Create subplots for each comedian
for index, comedian in enumerate(data.columns):
    wc.generate(data_clean.text)
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(full_names[index])
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-218661b9ef37> in <module>
#       8 # Create subplots for each comedian
#       9 for index, comedian in enumerate(data.columns):
# ---> 10     wc.generate(data_clean.text)
#      11
#      12     plt.subplot(3, 4, index+1)
#
# C:\Anaconda3\envs\spark\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'text'

# %% [markdown]
# ### Findings

# %% [markdown]
# * Ali Wong says the s-word a lot and talks about her husband. I guess that's funny to me.
# * A lot of people use the F-word. Let's dig into that later.

# %% [markdown]
# ## Number of Words

# %% [markdown]
# ### Analysis

# %%
# Find the number of unique words that each comedian uses

# Identify the non-zero items in the document-term matrix, meaning that the word occurs at least once
unique_list = []
for comedian in data.columns:
    uniques = data[comedian].to_numpy().nonzero()[0].size
    unique_list.append(uniques)

# Create a new dataframe that contains this unique word count
data_words = pd.DataFrame(list(zip(full_names, unique_list)), columns=['comedian', 'unique_words'])
data_unique_sort = data_words.sort_values(by='unique_words')
data_unique_sort

# %%
# Calculate the words per minute of each comedian

# Find the total number of words that a comedian uses
total_list = []
for comedian in data.columns:
    totals = sum(data[comedian])
    total_list.append(totals)
    
# Comedy special run times from IMDB, in minutes
run_times = [60, 59, 80, 60, 67, 73, 77, 63, 62, 58, 76, 79]

# Let's add some columns to our dataframe
data_words['total_words'] = total_list
data_words['run_times'] = run_times
data_words['words_per_minute'] = data_words['total_words'] / data_words['run_times']

# Sort the dataframe by words per minute to see who talks the slowest and fastest
data_wpm_sort = data_words.sort_values(by='words_per_minute')
data_wpm_sort

# %%
# Let's plot our findings
import numpy as np

y_pos = np.arange(len(data_words))

plt.subplot(1, 2, 1)
plt.barh(y_pos, data_unique_sort.unique_words, align='center')
plt.yticks(y_pos, data_unique_sort.comedian)
plt.title('Number of Unique Words', fontsize=20)

plt.subplot(1, 2, 2)
plt.barh(y_pos, data_wpm_sort.words_per_minute, align='center')
plt.yticks(y_pos, data_wpm_sort.comedian)
plt.title('Number of Words Per Minute', fontsize=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * **Vocabulary**
#    * Ricky Gervais (British comedy) and Bill Burr (podcast host) use a lot of words in their comedy
#    * Louis C.K. (self-depricating comedy) and Anthony Jeselnik (dark humor) have a smaller vocabulary
#
#
# * **Talking Speed**
#    * Joe Rogan (blue comedy) and Bill Burr (podcast host) talk fast
#    * Bo Burnham (musical comedy) and Anthony Jeselnik (dark humor) talk slow
#
# Ali Wong is somewhere in the middle in both cases. Nothing too interesting here.

# %% [markdown]
# ## Amount of Profanity

# %% [markdown]
# ### Analysis

# %%
# Earlier I said we'd revisit profanity. Let's take a look at the most common words again.
Counter(words).most_common()

# %%
# Let's isolate just these bad words
data_bad_words = data.transpose()[['fucking', 'fuck', 'shit']]
data_profanity = pd.concat([data_bad_words.fucking + data_bad_words.fuck, data_bad_words.shit], axis=1)
data_profanity.columns = ['f_word', 's_word']
data_profanity

# %%
# Let's create a scatter plot of our findings
plt.rcParams['figure.figsize'] = [10, 8]

for i, comedian in enumerate(data_profanity.index):
    x = data_profanity.f_word.loc[comedian]
    y = data_profanity.s_word.loc[comedian]
    plt.scatter(x, y, color='blue')
    plt.text(x+1.5, y+0.5, full_names[i], fontsize=10)
    plt.xlim(-5, 155) 
    
plt.title('Number of Bad Words Used in Routine', fontsize=20)
plt.xlabel('Number of F Bombs', fontsize=15)
plt.ylabel('Number of S Words', fontsize=15)

plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * **Averaging 2 F-Bombs Per Minute!** - I don't like too much swearing, especially the f-word, which is probably why I've never heard of Bill Bur, Joe Rogan and Jim Jefferies.
# * **Clean Humor** - It looks like profanity might be a good predictor of the type of comedy I like. Besides Ali Wong, my two other favorite comedians in this group are John Mulaney and Mike Birbiglia.

# %% [markdown]
# ## Side Note

# %% [markdown]
# What was our goal for the EDA portion of our journey? **To be able to take an initial look at our data and see if the results of some basic analysis made sense.**
#
# My conclusion - yes, it does, for a first pass. There are definitely some things that could be better cleaned up, such as adding more stop words or including bi-grams. But we can save that for another day. The results, especially the profanity findings, are interesting and make general sense, so we're going to move on.
#
# As a reminder, the data science process is an interative one. It's better to see some non-perfect but acceptable results to help you quickly decide whether your project is a dud or not, instead of having analysis paralysis and never delivering anything.
#
# **Alice's data science (and life) motto: Let go of perfectionism!**

# %% [markdown]
# ## Additional Exercises

# %% [markdown]
# 1. What other word counts do you think would be interesting to compare instead of the f-word and s-word? Create a scatter plot comparing them.
