# %%
import pickle
import pandas as pd

# %%
df = pd.read_pickle('fadlizon.pkl')

# %%
df = df[[0,2]]

# %%
#kombinasi semua row jadi 1 string
df = pd.DataFrame({'user': ['fadlizon'],'text': [df[2].str.cat(sep=' ')]})

# %%
df.head()
# Out:
#        user                                               text
# 0  fadlizon  Risma Mengamuk Soal Mobil PCR, Fadli Zon Sindi...

# %%
df.text[0]
# Out:
# 'Risma Mengamuk Soal Mobil PCR, Fadli Zon Sindir: Heran Kok Sering Sekali Ngamuk, Gak Ada Cara Lain? Pertanyakan Kasus Ruslan Buton, Fadli Zon: Standar Demokrasi Macam Apa Yang Kita Pakai? https://idtoday.co/hukum/pertanyakan-kasus-ruslan-buton-fadli-zon-standar-demokrasi-macam-apa-yang-kita-pakai/ lewat @idtodayco Ruslan Buton Ditangkap Gara-gara Minta Jokowi Mundur, Fadli Zon: Hadeuh Demokrasi Abal-abal https://pojoksatu.id/news/berita-nasional/2020/05/30/ruslan-buton-ditangkap-gara-gara-minta-jokowi-mundur-fadli-zon-hadeuh-demokrasi-abal-abal/ @PojokSatu Soal Penangkapan Ruslan Buton, Fadli Zon: Hadeuh, Ini Demokrasi Abal-abal Soal Penangkapan Ruslan Buton, Fadli Zon: Hadeuh, Ini Demokrasi Abal-abal https://rmol.id/amp/2020/05/30/436922/Soal-Penangkapan-Ruslan-Buton--Fadli-Zon--Hadeuh--Ini-Demokrasi-Abal-abal- Heran Bu Risma Ngamuk Lagi, Fadli Zon: Ngeri Ah.. #BuRisma via @jpnncom Heran Bu Risma Ngamuk Lagi, Fadli Zon: Ngeri Ah.. https://halloindo.com/jpnn/2020/05/30/heran-bu-rism
# ...

# %%
fg = pd.read_pickle('fahrihamzah.pkl')

# %%
hi = pd.read_pickle('msaid_didu.pkl')

# %%
frames = [df, fg, hi]
dg = pd.concat(frames)

# %%
dg
# Out:
#          user                                               text
# 0    fadlizon  Risma Mengamuk Soal Mobil PCR, Fadli Zon Sindi...
# 0       fahri  Sssssstt...\nRahasia...😂 https://t.co/YRC4lcrI...
# 0  msaid_didu  RT @vintenas: Washington DC, militer dipanggil...

# %%
dgg = pd.DataFrame(dgg.text.apply(round2))

# %%
dgg['user'] = ['fadlizon', 'fahri', 'msaid']

# %%
df = df.text.apply(round1)

# %%
df[0]
# Out:
# 'risma mengamuk soal mobil pcr fadli zon sindir heran kok sering sekali ngamuk gak ada cara lain pertanyakan kasus ruslan buton fadli zon standar demokrasi macam apa yang kita pakai  lewat idtodayco ruslan buton ditangkap garagara minta jokowi mundur fadli zon hadeuh demokrasi abalabal  pojoksatu soal penangkapan ruslan buton fadli zon hadeuh ini demokrasi abalabal soal penangkapan ruslan buton fadli zon hadeuh ini demokrasi abalabal  heran bu risma ngamuk lagi fadli zon ngeri ah burisma via jpnncom heran bu risma ngamuk lagi fadli zon ngeri ah  bu risma ngamuk fadli zon bilang begini ruslan buton ditangkap usai minta jokowi mundur fadli zon standar demokrasi macam apa yang kita pakai wali kota surabaya marah garagara mobil pcr fadli zon emangnya ngamuk menyelesaikan masalah heran bu risma ngamuk lagi fadli zon ngeri ah burisma via jpnncom  soal penangkapan ruslan buton fadli zon hadeuh ini demokrasi abalabal  wali kota surabaya marah garagara mobil pcr fadli zon emangnya ngamuk meny
# ...

# %%
dd = pd.read_csv('ua.csv')

# %%
dd = dd[0:1999]

# %%
dd.columns = ['user','text']
dd.user = 'hashtag'
dd = pd.DataFrame({'user': ["hashtag"], 'text': [dd.text.str.cat(sep=' ')]})
dd.head()
# Out:
#       user                                               text
# 0  hashtag  b'@D4tuk_T4mburin @PolitikusBadut \xf0\x9f\x91...

# %%
# Apply a first round of text cleaning techniques
import re
import string

def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = re.sub('(http|https|ftp|ftps)\:\/\/[a-zA-Z0-9\-\.]+\.[a-zA-Z]{2,3}(\/\S*)?','',text)
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

round1 = lambda x: clean_text_round1(x)

# %%
# Apply a second round of cleaning
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
import nltk
text = nltk.tokenize.word_tokenize(df['text'][0])

# %%
dd = dd.text.apply(round1)

# %%
text = dd[0]

# %%
ar
# Out:
# [(',', 2238),
#  ('.', 1799),
#  (':', 1081),
#  ('Fadli', 971),
#  ('Zon', 935),
#  ('di', 458),
#  ('@', 391),
#  ('yg', 325),
#  ('ini', 315),
#  ('Pemerintah', 302),
#  ('dan', 292),
#  ('https', 244),
#  ('?', 227),
#  (')', 220),
#  ('(', 215),
#  ('Covid-19', 214),
#  ('Jokowi', 205),
#  ('-', 192),
#  ('n', 192),
#  ('untuk', 190),
#  ('Indonesia', 185),
#  ('yang', 166),
#  ('http', 164),
#  ('kita', 163),
#  ('#', 154),
#  ('Corona', 142),
#  ('“', 138),
#  ('”', 133),
#  ('tak', 132),
#  ('Ini', 131),
#  ('itu', 128),
#  ('Tak', 123),
#  ('dari', 122),
#  ('bisa', 114),
#  ('Presiden', 112),
#  ('ke', 111),
#  ('dengan', 106),
#  ('sy', 106),
#  ('ada', 105),
#  ('dalam', 101),
#  ('!', 97),
#  ('atau', 95),
#  ('Rakyat', 86),
#  ('akan', 86),
#  ('|', 83),
#  ('Perppu', 82),
#  ('2020', 80),
#  ('PSBB', 79),
#  ('lebih', 78),
#  ('oleh', 77),
#  ('pemerintah', 77),
#  ('New', 73),
#  ('adalah', 73),
#  ('juga', 72),
#  ('Kita', 71),
#  ('Jangan', 71),
# ...

# %%
file_stopwords = '../datatextml/indonesian-wordlist/indonesian-stopwords-complete.txt'
f = open(file_stopwords,'rt')
stopwords = f.readlines()
for ind,isi in enumerate(stopwords):
    stopwords[ind]=isi.rstrip()
f.close()

# %%
# HILANGKAN STOPWORDS
for ind, isi in enumerate(text):
    words = [w for w in isi if not w in stopwords]
    text[ind] = words
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-9e888f34c3fa> in <module>
#       2 for ind, isi in enumerate(text):
#       3     words = [w for w in isi if not w in stopwords]
# ----> 4     text[ind] = words
#
# TypeError: 'str' object does not support item assignment

# %%
text
# Out:
# ' politikusbadut   brt marshase saya udah  tahun gak nonton tvri tapi bolehkan naikin hestek boikottvrinndirutbokep  brt marshase saya udah  tahun gak nonton tvri tapi bolehkan naikin hestek boikottvrinndirutbokep  bsuka kesel sama yg bilangnaku yang jelek bisa apa cuman sampahnnpadahal mukany glowing putih cakep lah   brt marshase saya udah  tahun gak nonton tvri tapi bolehkan naikin hestek boikottvrinndirutbokep  brt tijabar risma marah besar dituding tidak bisa kerja siapa yang enggak bisa kerjannyang nuding tega bener sih jalanan  brt tijabar risma marah besar dituding tidak bisa kerja siapa yang enggak bisa kerjannyang nuding tega bener sih jalanan  boposisicerdas sandiwara  brt qiraniayra ekonomi hancur rakyat babak belur yg dibutuhkan bkn new normal tpi new leadernnjangan biarkan kapal besar ini karam  baya aya waee dirutbokep brt tijabar risma marah besar dituding tidak bisa kerja siapa yang enggak bisa kerjannyang nuding tega bener sih jalanan  brt nadineoliv holaa gaeesdari
# ...

# %%
import nltk
text = nltk.tokenize.word_tokenize(df['text'][0])

# %%
from collections import Counter
# Let's first pull out the top 30 words for each comedian
ar = Counter(text).most_common()
